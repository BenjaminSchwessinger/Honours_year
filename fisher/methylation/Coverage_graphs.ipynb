# %% [markdown]
# # <span style='color:#a347ff'> Graph the test coverage files <span/>

# %%
# %matplotlib inline

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# define filepaths
IN_PATH = '/home/anjuni/analysis/coverage/test_coverage'

te_100kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.TE.sorted.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
gene_100kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.anno.sorted.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
effector_100kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.effectors.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
ont_6mA_100kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_hc_tombo_sorted.cutoff.0.10.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
pb_6mA_100kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_prob_smrtlink_sorted.cutoff.0.10.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_5mC_100kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.cutoff.0.10.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_cpg_5mC_100kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.CpG.cutoff.0.10.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
np_5mC_100kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_nanopolish_sorted.cutoff.0.10.100kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])

# %%
te_100kb_df.head()
# Out:
#         Contig  Window Start  Window End  Depth  Fraction
# 0  pcontig_019             0      100000     58   0.29407
# 1  pcontig_019        100000      200000     24   0.09213
# 2  pcontig_019        200000      300000     10   0.05134
# 3  pcontig_019        300000      400000     68   0.18258
# 4  pcontig_019        400000      500000     26   0.07739

# %%
effector_100kb_df.head()
# Out:
#         Contig  Window Start  Window End  Depth  Fraction
# 0  pcontig_019             0      100000      0   0.00000
# 1  pcontig_019        100000      200000      6   0.04561
# 2  pcontig_019        200000      300000      1   0.00909
# 3  pcontig_019        300000      400000      0   0.00000
# 4  pcontig_019        400000      500000      0   0.00000

# %%
fig, ax = plt.subplots(figsize=(15, 7))
te_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')
tmb_5mC_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
tmb_cpg_5mC_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='hotpink')
gene_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')

# %%
plt.hist()

# %%
fig, ax = plt.subplots(figsize=(15, 7))
gene_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')
tmb_5mC_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
ont_6mA_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='deepskyblue')
effector_100kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')

# %% [markdown]
# # <span style='color:#d147ff'> 10kb windows <span/>

# %%
te_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.TE.sorted.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
gene_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.anno.sorted.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
effector_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.effectors.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
ont_6mA_10kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_hc_tombo_sorted.cutoff.0.10.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
pb_6mA_10kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_prob_smrtlink_sorted.cutoff.0.10.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_5mC_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.cutoff.0.10.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_cpg_5mC_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.CpG.cutoff.0.10.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
np_5mC_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_nanopolish_sorted.cutoff.0.10.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])

# %%
fig, ax = plt.subplots(figsize=(15, 7))
te_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')
tmb_5mC_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
tmb_cpg_5mC_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='hotpink')
gene_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')

# %%
fig, ax = plt.subplots(figsize=(15, 7))
gene_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')
tmb_5mC_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
ont_6mA_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='deepskyblue')
effector_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')

# %% [markdown]
# # <span style='color:#ff47ff'> 30kb windows <span/>

# %%
te_30kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.TE.sorted.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
gene_30kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.anno.sorted.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
effector_30kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.effectors.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
ont_6mA_30kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_hc_tombo_sorted.cutoff.0.10.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
pb_6mA_30kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_prob_smrtlink_sorted.cutoff.0.10.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_5mC_30kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.cutoff.0.10.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_cpg_5mC_30kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.CpG.cutoff.0.10.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
np_5mC_30kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_nanopolish_sorted.cutoff.0.10.30kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])

# %%
fig, ax = plt.subplots(figsize=(15, 7))
te_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')
tmb_5mC_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
tmb_cpg_5mC_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='hotpink')
gene_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')

# %%
fig, ax = plt.subplots(figsize=(15, 7))
gene_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')
tmb_5mC_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
ont_6mA_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='deepskyblue')
effector_30kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')

# %% [markdown]
# # <span style='color:#ff47d1'> 90% methylation prob files <span/>

# %%
te_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.TE.sorted.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
gene_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.anno.sorted.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
effector_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.effectors.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
ont_6mA_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_hc_tombo_sorted.cutoff.0.90.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
pb_6mA_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_prob_smrtlink_sorted.cutoff.0.90.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_5mC_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.cutoff.0.90.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_cpg_5mC_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.CpG.cutoff.0.90.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
np_5mC_90_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_nanopolish_sorted.cutoff.0.90.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])

# %%
fig, ax = plt.subplots(figsize=(15, 7))
te_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')
tmb_5mC_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
tmb_cpg_5mC_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='hotpink')
gene_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')

# %%
fig, ax = plt.subplots(figsize=(15, 7))
gene_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')
tmb_5mC_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
ont_6mA_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='deepskyblue')
effector_90_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')

# %%
#fig, ax = plt.subplots(figsize=(15, 7))
ont_6mA_90_10kb_df.hist(column='Fraction', bins=20)

#observation: coverage fraction skews left, does randomisation change the distribution?
#find the statistic test to see whether distribution of actual coverages is different from
#coverage of randomised sample
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f202a526320>]],
#       dtype=object)

# %%
np_5mC_90_10kb_df.hist(column='Fraction', bins=20) # put the same width as the tombo hist so they're comparable
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f202a3d59e8>]],
#       dtype=object)

# %%
np_5mC_10kb_df.hist(column='Fraction', bins=20) # put the same width as the tombo hist so they're comparable
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f202a355f60>]],
#       dtype=object)

# %%
tmb_5mC_90_10kb_df.hist(column='Fraction', bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f202a522278>]],
#       dtype=object)

# %%
tmb_5mC_10kb_df.hist(column='Fraction', bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f202a43a358>]],
#       dtype=object)

# %%
# repeat this randomisation test for all cutoffs
# choose the cutoff where the distribution isn't random anymore

# %% [markdown]
# # <span style='color:#ff47a3'> 50% methylation prob files <span/>

# %%
te_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.TE.sorted.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
gene_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.anno.sorted.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
effector_10kb_df = pd.read_csv(os.path.join(IN_PATH, 'Pst_104E_v13_ph_ctg.effectors.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
ont_6mA_50_10kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_hc_tombo_sorted.cutoff.0.50.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
pb_6mA_50_10kb_df = pd.read_csv(os.path.join(IN_PATH, '6mA_prob_smrtlink_sorted.cutoff.0.50.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_5mC_50_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.cutoff.0.50.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
tmb_cpg_5mC_50_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_tombo_sorted.CpG.cutoff.0.50.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])
np_5mC_50_10kb_df = pd.read_csv(os.path.join(IN_PATH, '5mC_hc_nanopolish_sorted.cutoff.0.50.10kb.overlap.bed'), sep = '\t', header = None, names = ['Contig', 'Window Start', 'Window End', 'Depth', 'Fraction'])

# %%
fig, ax = plt.subplots(figsize=(15, 7))
te_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')
tmb_5mC_50_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
tmb_cpg_5mC_50_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='hotpink')
gene_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')

# %%
fig, ax = plt.subplots(figsize=(15, 7))
gene_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='darkorchid')
tmb_5mC_50_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='dodgerblue')
ont_6mA_50_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='deepskyblue')
effector_10kb_df.plot(y='Fraction', x='Window Start', kind='line', ax=ax, color='yellowgreen')

# %% [markdown]
# There's a lot of noise on the 10kb window plots. Might try sliding windows next, now that the loops have been tested out :)
